# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !pip install mplfinance
# Out:
# Requirement already satisfied: mplfinance in /opt/anaconda3/lib/python3.13/site-packages (0.12.10b0)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.13/site-packages (from mplfinance) (3.10.0)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.13/site-packages (from mplfinance) (2.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib->mplfinance) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib->mplfinance) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib->mplfinance) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib->mplfinance) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib->mplfinance) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib->mplfinance) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib->mplfinance) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib->mplfinance) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib->mplfinance) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas->mplfinance) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas->mplfinance) (2025.2)

# %%
import mplfinance as mpf

# %%
df = pd.read_csv("nifty50_dataset.csv")

# %%
df.head()
# Out:
#          Date      Open      High       Low     Close  Volume
# 0  2018-01-01  10586.07  10683.86  10397.83  10561.57  246798
# 1  2018-01-02  10503.11  10717.04  10461.30  10549.73  412421
# 2  2018-01-03  10466.06  10551.28  10361.59  10499.47  357426
# 3  2018-01-04  10559.14  10636.70  10479.58  10566.33  241848
# 4  2018-01-05  10460.42  10617.42  10310.08  10465.02  354270

# %%
df.tail()
# Out:
#             Date     Open     High      Low    Close  Volume
# 1822  2024-12-25  7238.57  7331.09  7127.63  7256.51  279363
# 1823  2024-12-26  7507.58  7567.90  7390.80  7475.75  479105
# 1824  2024-12-27  7542.92  7560.61  7401.85  7521.49  402743
# 1825  2024-12-30  7660.16  7733.64  7624.96  7641.91  360076
# 1826  2024-12-31  7639.95  7786.61  7562.48  7669.63  433190

# %%
df.sample(5)
# Out:
#             Date      Open      High       Low     Close  Volume
# 368   2019-05-30  11734.41  11820.88  11572.44  11700.64  244235
# 1211  2022-08-23  10590.26  10662.93  10461.70  10572.38  214744
# 507   2019-12-11  10759.97  10820.67  10578.41  10748.39  395491
# 1666  2024-05-21   6790.23   6914.79   6765.26   6798.66  376308
# 554   2020-02-14   8717.41   8732.51   8585.04   8689.88  470582

# %%
df.isnull().any()
# Out:
# Date      False
# Open      False
# High      False
# Low       False
# Close     False
# Volume    False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1827 entries, 0 to 1826
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1827 non-null   object
#  1   Open    1827 non-null   float64
#  2   High    1827 non-null   float64
#  3   Low     1827 non-null   float64
#  4   Close   1827 non-null   float64
#  5   Volume  1827 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 85.8+ KB

# %%
df.describe()
# Out:
#                Open          High           Low         Close         Volume
# count   1827.000000   1827.000000   1827.000000   1827.000000    1827.000000
# mean    9629.508796   9726.394877   9533.183366   9630.042978  347662.818829
# std     2070.213816   2092.123014   2050.244315   2069.966807   85860.131091
# min     5973.400000   6012.870000   5898.000000   6000.000000  200068.000000
# 25%     7513.330000   7568.465000   7413.635000   7497.895000  272968.500000
# 50%     9756.690000   9854.160000   9682.670000   9762.490000  346685.000000
# 75%    11220.495000  11341.525000  11095.735000  11216.855000  420326.000000
# max    13432.440000  13555.130000  13318.910000  13440.810000  499915.000000

# %%
df.shape
# Out:
# (1827, 6)

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
plt.plot(df['Date'], df['Close'])

# %%
plt.plot(df['Date'], df['Volume'])

# %%
plt.figure(figsize=(10,6))

sns.heatmap(
    df.select_dtypes(include='number').corr(),
    annot=True,
    cmap='coolwarm'
)

plt.title("Correlation Heatmap")
plt.show()

# %%
sns.boxplot(x=df['Close'])
# Out:
# <Axes: xlabel='Close'>

# %%
df['Date'] = pd.to_datetime(df['Date'])

df.set_index('Date', inplace=True)

# %%
mpf.plot(
    df.tail(30),
    type='candle',
    style='charles',
    mav=(10,20),
    volume=True,
    figsize=(14,8),
    title='Last 30 Days NIFTY50'
)

# %%
sns.histplot(df['Close'], bins=30)
# Out:
# <Axes: xlabel='Close', ylabel='Count'>
